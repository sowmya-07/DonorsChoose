# %%
import numpy as np
import pandas as pd
#from pandas_profiling import ProfileReport
import os

# %%
data_proj = pd.read_csv('/Users/sowmy/Documents/JigsawAcad/CapstonProject_1/projects.csv/projects.csv')

# %%
data_proj.columns
# Out:
# Index(['projectid', 'teacher_acctid', 'schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_state',
#        'school_zip', 'school_metro', 'school_district', 'school_county',
#        'school_charter', 'school_magnet', 'school_year_round', 'school_nlns',
#        'school_kipp', 'school_charter_ready_promise', 'teacher_prefix',
#        'teacher_teach_for_america', 'teacher_ny_teaching_fellow',
#        'primary_focus_subject', 'primary_focus_area',
#        'secondary_focus_subject', 'secondary_focus_area', 'resource_type',
#        'poverty_level', 'grade_level', 'fulfillment_labor_materials',
#        'total_price_excluding_optional_support',
#        'total_price_including_optional_support', 'students_reached',
#        'eligible_double_your_impact_match', 'eligible_almost_home_match',
#        'date_posted'],
#       dtype='object')

# %%
data_proj.shape
# Out:
# (664098, 35)

# %%
q20 = data_proj.quantile(0.20)

# %%
pro_des = data_proj.describe(include='all')

# %%
pro_des
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     975fc9673b34a75456445fb9e7ea7001  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %%
#data_projc = data_proj.describe().to_csv("data_proje.csv)
pd.DataFrame(pro_des)
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     975fc9673b34a75456445fb9e7ea7001  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %%
q20
# Out:
# school_ncesid                             6.344101e+10
# school_latitude                           3.378270e+01
# school_longitude                         -1.179084e+02
# school_zip                                2.078200e+04
# fulfillment_labor_materials               1.700000e+01
# total_price_excluding_optional_support    2.376400e+02
# total_price_including_optional_support    2.827900e+02
# students_reached                          2.000000e+01
# Name: 0.2, dtype: float64

# %%
pro_des.head()
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     975fc9673b34a75456445fb9e7ea7001  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
# mean                                 NaN                               NaN
#
#                                 schoolid  school_ncesid  school_latitude  \
# count                             664098   6.213620e+05    664098.000000
# unique                             57004            NaN              NaN
# top     9231edfbd3aa42675e70e69aea8b0a36            NaN              NaN
# freq                                 944            NaN              NaN
# mean                                 NaN   2.608577e+11        37.240948
#
# ...

# %%
pro_des = pro_des.T

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean                  std            min  \
# projectid                        NaN                  NaN            NaN
# teacher_acctid                   NaN                  NaN            NaN
# schoolid                         NaN                  NaN            NaN
# school_ncesid    260857694688.375427  158975385133.582855  10000500870.0
# school_latitude            37.240948             4.668155       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
pro_des.shape
# Out:
# (35, 11)

# %%
pro_des['q20'] = q20

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean                  std            min  \
# projectid                        NaN                  NaN            NaN
# teacher_acctid                   NaN                  NaN            NaN
# schoolid                         NaN                  NaN            NaN
# school_ncesid    260857694688.375427  158975385133.582855  10000500870.0
# school_latitude            37.240948             4.668155       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
q5 = data_proj.quantile(0.05)
q5
# Out:
# school_ncesid                             6.047401e+10
# school_latitude                           2.955562e+01
# school_longitude                         -1.222543e+02
# school_zip                                8.610000e+03
# fulfillment_labor_materials               9.000000e+00
# total_price_excluding_optional_support    1.522385e+02
# total_price_including_optional_support    1.811185e+02
# students_reached                          1.200000e+01
# Name: 0.05, dtype: float64

# %%
pro_des['q5'] = q5

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean                  std            min  \
# projectid                        NaN                  NaN            NaN
# teacher_acctid                   NaN                  NaN            NaN
# schoolid                         NaN                  NaN            NaN
# school_ncesid    260857694688.375427  158975385133.582855  10000500870.0
# school_latitude            37.240948             4.668155       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
q10 = data_proj.quantile(0.1)
q10
# Out:
# school_ncesid                             6.227100e+10
# school_latitude                           3.062453e+01
# school_longitude                         -1.213731e+02
# school_zip                                1.047200e+04
# fulfillment_labor_materials               9.000000e+00
# total_price_excluding_optional_support    1.789400e+02
# total_price_including_optional_support    2.129100e+02
# students_reached                          1.800000e+01
# Name: 0.1, dtype: float64

# %%
pro_des['q10'] = q10

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean                  std            min  \
# projectid                        NaN                  NaN            NaN
# teacher_acctid                   NaN                  NaN            NaN
# schoolid                         NaN                  NaN            NaN
# school_ncesid    260857694688.375427  158975385133.582855  10000500870.0
# school_latitude            37.240948             4.668155       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
q85 = data_proj.quantile(0.85)
q85
# Out:
# school_ncesid                             4.503540e+11
# school_latitude                           4.176907e+01
# school_longitude                         -7.431902e+01
# school_zip                                9.160100e+04
# fulfillment_labor_materials               3.500000e+01
# total_price_excluding_optional_support    7.633600e+02
# total_price_including_optional_support    9.049600e+02
# students_reached                          1.500000e+02
# Name: 0.85, dtype: float64

# %%
pro_des['q85'] = q85

# %%
q95 = data_proj.quantile(0.95)
q95
# Out:
# school_ncesid                             5.002820e+11
# school_latitude                           4.353684e+01
# school_longitude                         -7.382772e+01
# school_zip                                9.512500e+04
# fulfillment_labor_materials               3.500000e+01
# total_price_excluding_optional_support    1.076020e+03
# total_price_including_optional_support    1.283760e+03
# students_reached                          4.000000e+02
# Name: 0.95, dtype: float64

# %%
pro_des['q95'] = q95

# %%
q99 = data_proj.quantile(0.99)
q99
# Out:
# school_ncesid                             5.505250e+11
# school_latitude                           4.751781e+01
# school_longitude                         -7.106244e+01
# school_zip                                9.814600e+04
# fulfillment_labor_materials               3.500000e+01
# total_price_excluding_optional_support    2.387903e+03
# total_price_including_optional_support    2.848683e+03
# students_reached                          8.000000e+02
# Name: 0.99, dtype: float64

# %%
pro_des['q99'] = q99

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean                  std            min  \
# projectid                        NaN                  NaN            NaN
# teacher_acctid                   NaN                  NaN            NaN
# schoolid                         NaN                  NaN            NaN
# school_ncesid    260857694688.375427  158975385133.582855  10000500870.0
# school_latitude            37.240948             4.668155       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
mis = data_proj.isnull().sum()
mis
# Out:
# projectid                                      0
# teacher_acctid                                 0
# schoolid                                       0
# school_ncesid                              42736
# school_latitude                                0
# school_longitude                               0
# school_city                                    0
# school_state                                   0
# school_zip                                     4
# school_metro                               81908
# school_district                              948
# school_county                                 17
# school_charter                                 0
# school_magnet                                  0
# school_year_round                              0
# school_nlns                                    0
# school_kipp                                    0
# school_charter_ready_promise                   0
# teacher_prefix                                 4
# ...

# %%
pro_des['missing'] = mis

# %%
pro_des.head(10)
# Out:
#                      count  unique                               top    freq  \
# projectid           664098  664098  975fc9673b34a75456445fb9e7ea7001       1
# teacher_acctid      664098  249555  787720cc575e3204991b8ca18d312d2b     266
# schoolid            664098   57004  9231edfbd3aa42675e70e69aea8b0a36     944
# school_ncesid     621362.0     NaN                               NaN     NaN
# school_latitude   664098.0     NaN                               NaN     NaN
# school_longitude  664098.0     NaN                               NaN     NaN
# school_city         664098    9007                           Chicago   28435
# school_state        664098      52                                CA  126242
# school_zip        664094.0     NaN                               NaN     NaN
# school_metro        582190       3                             urban  349703
#
#                                  mean                  std            min  \
# ...

# %%
std = data_proj.std()
std
# Out:
# school_ncesid                             1.589754e+11
# school_latitude                           4.668155e+00
# school_longitude                          1.776191e+01
# school_zip                                3.119374e+04
# fulfillment_labor_materials               8.663046e+00
# total_price_excluding_optional_support    1.267738e+04
# total_price_including_optional_support    1.545863e+04
# students_reached                          2.283328e+03
# dtype: float64

# %%
pro_des['std'] = std

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean           std            min  \
# projectid                        NaN           NaN            NaN
# teacher_acctid                   NaN           NaN            NaN
# schoolid                         NaN           NaN            NaN
# school_ncesid    260857694688.375427  1.589754e+11  10000500870.0
# school_latitude            37.240948  4.668155e+00       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
obs = data_proj.shape[0]
obs
# Out:
# 664098

# %%
pro_des['obs'] = obs

# %%
pro_des.head()
# Out:
#                     count  unique                               top freq  \
# projectid          664098  664098  975fc9673b34a75456445fb9e7ea7001    1
# teacher_acctid     664098  249555  787720cc575e3204991b8ca18d312d2b  266
# schoolid           664098   57004  9231edfbd3aa42675e70e69aea8b0a36  944
# school_ncesid    621362.0     NaN                               NaN  NaN
# school_latitude  664098.0     NaN                               NaN  NaN
#
#                                 mean           std            min  \
# projectid                        NaN           NaN            NaN
# teacher_acctid                   NaN           NaN            NaN
# schoolid                         NaN           NaN            NaN
# school_ncesid    260857694688.375427  1.589754e+11  10000500870.0
# school_latitude            37.240948  4.668155e+00       18.24914
#
#                             25%             50%             75%  \
# ...

# %%
miss_perc = data_proj.isnull().sum()*100/len(data_proj)
miss_perc
# Out:
# projectid                                  0.000000
# teacher_acctid                             0.000000
# schoolid                                   0.000000
# school_ncesid                              6.435195
# school_latitude                            0.000000
# school_longitude                           0.000000
# school_city                                0.000000
# school_state                               0.000000
# school_zip                                 0.000602
# school_metro                              12.333722
# school_district                            0.142750
# school_county                              0.002560
# school_charter                             0.000000
# school_magnet                              0.000000
# school_year_round                          0.000000
# school_nlns                                0.000000
# school_kipp                                0.000000
# school_charter_ready_promise               0.000000
# ...

# %%
pro_des['missing_perc'] = miss_perc

# %%
pro_des = pro_des.reindex(columns = ['mean','std','obs','count', 'missing', 'missing_perc', 'min', 'max', 'unique', 'q5', 'q10', '25%', 
                         '50%', '75%', 'q85', 'q95', 'q99'])

# %%
pro_des.fillna('NotApplicable', inplace=True)

# %%
pro_des.head(35)
# Out:
#                                                        mean  \
# projectid                                     NotApplicable
# teacher_acctid                                NotApplicable
# schoolid                                      NotApplicable
# school_ncesid                           260857694688.375427
# school_latitude                                   37.240948
# school_longitude                                  -93.34476
# school_city                                   NotApplicable
# school_state                                  NotApplicable
# school_zip                                     52926.452644
# school_metro                                  NotApplicable
# school_district                               NotApplicable
# school_county                                 NotApplicable
# school_charter                                NotApplicable
# school_magnet                                 NotApplicable
# school_year_round                             NotApplicable
# ...

# %%
data_proj.shape[0]
# Out:
# 664098

# %%
pro_des.to_csv('project_DQR.csv')
