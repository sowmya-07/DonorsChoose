# %%
import numpy as np
import pandas as pd
import os

# %%
data_essa = pd.read_csv('/Users/sowmy/Documents/JigsawAcad/CapstonProject_1/essays.csv/essays.csv')

# %%
data_essa.columns
# Out:
# Index(['projectid', 'teacher_acctid', 'title', 'short_description',
#        'need_statement', 'essay'],
#       dtype='object')

# %%
data_essa.shape
# Out:
# (664098, 6)

# %%
de = data_essa.describe(include='all')

# %%
de.head()
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     6aa302b6c74352516e798a937c225b70  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
#
#                        title  \
# count                 664081
# unique                570117
# top     Can You Hear Me Now?
# freq                     574
#
#                                         short_description  \
# count                                              663966
# unique                                             641701
# top     Do you remember what it was like the first tim...
# freq                                                  144
#
#                              need_statement  \
# count                                662626
# unique                               639965
# ...

# %%
pd.DataFrame(de)
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     6aa302b6c74352516e798a937c225b70  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
#
#                        title  \
# count                 664081
# unique                570117
# top     Can You Hear Me Now?
# freq                     574
#
#                                         short_description  \
# count                                              663966
# unique                                             641701
# top     Do you remember what it was like the first tim...
# freq                                                  144
#
#                              need_statement  \
# count                                662626
# unique                               639965
# ...

# %%
de.head()
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     6aa302b6c74352516e798a937c225b70  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
#
#                        title  \
# count                 664081
# unique                570117
# top     Can You Hear Me Now?
# freq                     574
#
#                                         short_description  \
# count                                              663966
# unique                                             641701
# top     Do you remember what it was like the first tim...
# freq                                                  144
#
#                              need_statement  \
# count                                662626
# unique                               639965
# ...

# %%
de.head()
# Out:
#                                projectid                    teacher_acctid  \
# count                             664098                            664098
# unique                            664098                            249555
# top     6aa302b6c74352516e798a937c225b70  787720cc575e3204991b8ca18d312d2b
# freq                                   1                               266
#
#                        title  \
# count                 664081
# unique                570117
# top     Can You Hear Me Now?
# freq                     574
#
#                                         short_description  \
# count                                              663966
# unique                                             641701
# top     Do you remember what it was like the first tim...
# freq                                                  144
#
#                              need_statement  \
# count                                662626
# unique                               639965
# ...

# %%
de = de.T

# %%
de
# Out:
#                     count  unique  \
# projectid          664098  664098
# teacher_acctid     664098  249555
# title              664081  570117
# short_description  663966  641701
# need_statement     662626  639965
# essay              664095  662831
#
#                                                                  top freq
# projectid                           6aa302b6c74352516e798a937c225b70    1
# teacher_acctid                      787720cc575e3204991b8ca18d312d2b  266
# title                                           Can You Hear Me Now?  574
# short_description  Do you remember what it was like the first tim...  144
# need_statement                   My students need a document camera.  769
# essay              I am a K-5 general music teacher at Vinson-Byn...   16

# %%
obs = data_essa.shape[0]
obs
# Out:
# 664098

# %%
de['obs'] = obs

# %%
de.head()
# Out:
#                     count  unique  \
# projectid          664098  664098
# teacher_acctid     664098  249555
# title              664081  570117
# short_description  663966  641701
# need_statement     662626  639965
#
#                                                                  top freq  \
# projectid                           6aa302b6c74352516e798a937c225b70    1
# teacher_acctid                      787720cc575e3204991b8ca18d312d2b  266
# title                                           Can You Hear Me Now?  574
# short_description  Do you remember what it was like the first tim...  144
# need_statement                   My students need a document camera.  769
#
#                       obs
# projectid          664098
# teacher_acctid     664098
# title              664098
# short_description  664098
# need_statement     664098

# %%
de.to_csv('esaay_DQR.csv')
